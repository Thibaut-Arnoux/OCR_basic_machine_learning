# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
house_data = pd.read_csv('house.csv')
house_data = house_data[house_data['loyer'] < 10_000]

# %%
house_data
# Out:
#      loyer  surface
# 0     1330       37
# 1     1400       32
# 2      904       26
# 3      955       30
# 4     2545       70
# ..     ...      ...
# 540   1490       48
# 541   2020       58
# 542   2050       70
# 543   1220       42
# 544   1610       44
#
# [536 rows x 2 columns]

# %%
plt.scatter(house_data['surface'], house_data['loyer'])

# %%
X = np.array([house_data['surface']]).T
X
# Out:
# array([[ 37],
#        [ 32],
#        [ 26],
#        [ 30],
#        [ 70],
#        [ 24],
#        [ 41],
#        [ 67],
#        [ 63],
#        [ 70],
#        [ 81],
#        [ 26],
#        [ 36],
#        [ 19],
#        [ 20],
#        [ 25],
#        [ 35],
#        [120],
#        [ 40],
#        [ 30],
#        [ 25],
#        [ 21],
#        [ 44],
#        [ 35],
#        [ 54],
#        [ 39],
#        [ 34],
#        [ 28],
#        [ 32],
#        [ 40],
#        [ 42],
#        [ 31],
#        [ 33],
#        [ 39],
#        [ 47],
#        [ 33],
#        [ 37],
#        [ 42],
#        [ 46],
#        [ 37],
#        [ 46],
#        [ 42],
#        [ 49],
#        [ 48],
#        [ 50],
#        [ 54],
#        [ 54],
#        [ 45],
#        [ 53],
#        [ 40],
#        [ 35],
#        [ 40],
#        [ 35],
#        [ 60],
#        [ 30],
#        [ 34],
#        [ 64],
#        [ 47],
#        [ 43],
#        [ 62],
#        [ 50],
#        [ 53],
# ...

# %%
y = np.array([house_data['loyer']]).T
y
# Out:
# array([[1330],
#        [1400],
#        [ 904],
#        [ 955],
#        [2545],
#        [ 970],
#        [1560],
#        [1960],
#        [2000],
#        [2600],
#        [3280],
#        [ 980],
#        [1250],
#        [ 752],
#        [ 815],
#        [1147],
#        [1500],
#        [3587],
#        [1355],
#        [1245],
#        [1100],
#        [1120],
#        [1225],
#        [1250],
#        [1280],
#        [1114],
#        [1290],
#        [1300],
#        [1300],
#        [1304],
#        [1340],
#        [1344],
#        [1290],
#        [1364],
#        [1400],
#        [1400],
#        [1420],
#        [1420],
#        [1445],
#        [1500],
#        [1544],
#        [1550],
#        [1500],
#        [1612],
#        [1650],
#        [1533],
#        [1663],
#        [1584],
#        [1680],
#        [1700],
#        [1700],
#        [1700],
#        [1700],
#        [1700],
#        [1600],
#        [1700],
#        [1710],
#        [1600],
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(X, y)
reg.coef_.item(0)
plt.plot([0, 250], [reg.coef_.item(0), 250 * reg.coef_.item(0)], linestyle='--')
plt.scatter(house_data['surface'], house_data['loyer'])
plt.show()
